# %% [markdown]
# ## Step 1: Retrive the list of PubmedID and PMC IDs about a particular Disease

# %% [markdown]
# ### Use Entrez to Search PubMed and Fetch Details ( Using E-utilities API.)

# %%
from Bio import Entrez
import requests
import json
import requests
import json
import os
import time  

# Always provide your email when using NCBI's API
Entrez.email = "enock.niyonkuru@jax.org"
# Out:
# /Users/niyone/Desktop/maxo/venv/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
def search_articles(disease_name, max_results=200):
    """
    Search articles related to a disease and return their PubMed IDs.
    """
    search_term = f"{disease_name}[Title/Abstract]"
    handle = Entrez.esearch(db="pubmed", term=search_term, retmax=max_results)
    record = Entrez.read(handle)
    handle.close()
    return record["IdList"]

def fetch_pmc_ids(pmids_list):
    """
    Fetch PMC IDs corresponding to a list of PubMed IDs, and return three lists:
    - pmids_without_pmc: PubMed IDs without corresponding PMC IDs
    - pmc_ids_list: PMC IDs in the format 'PMC12345'
    - pmids_with_pmc: PubMed IDs with corresponding PMC IDs
    """
    links = Entrez.elink(dbfrom="pubmed", db="pmc", id=pmids_list, linkname="pubmed_pmc")
    records = Entrez.read(links)
    links.close()
    
    pmc_ids_list = []    
    for record in records:
        pmid = record['IdList'][0]
        try:
            pmc_id = 'PMC' + record['LinkSetDb'][0]['Link'][0]['Id']
            pmc_ids_list.append(pmc_id)
        except IndexError:  # This PMID does not have a corresponding PMC ID
            continue
    
    # Convert sets to lists for the return value
    return  pmc_ids_list

# %%
# Example usage
disease_name = "Sickle Cell Anemia"
pmids_list = search_articles(disease_name)
pmc_ids_list = fetch_pmc_ids(pmids_list)

# %%
print("Length of PM IDs:", len(pmids_list))
print("PM IDs:", pmids_list[:5])

print("Length of PMC IDs:", len(pmc_ids_list))
print("PMC IDs:", pmc_ids_list[:5])
# Out:
# Length of PM IDs: 200
# PM IDs: ['38344818', '38336101', '38335412', '38332651', '38326178']
# Length of PMC IDs: 113
# PMC IDs: ['PMC10834466', 'PMC10838028', 'PMC10825386', 'PMC10807523', 'PMC10809526']

# %% [markdown]
# ## Step 2: Use Pubtator API to get the Annotated Texts for the selected IDs

# %% [markdown]
# #### Abstract + Title  Text

# %%
def fetch_and_save_abst_json(pmids_list, base_path, max_articles_to_save):
    """
    Fetches full texts for given PMC IDs in biocjson format and saves them as JSON files in the specified folder.
    Tracks the count of articles not found and successfully retrieved. Stops saving articles once a specified limit is reached.
    
    Parameters:
    - pmids_list (list of str): List of PMC IDs.
    - base_path (str): The base directory path where the files will be saved.
    - max_articles_to_save (int): Maximum number of articles to save before ending the function.
    """
    not_found_count = 0
    found_count = 0

    for pmid in pmids_list:
        if found_count >= max_articles_to_save:
            break  # End the loop if the maximum number of articles to save has been reached
        
        api_url = f"https://www.ncbi.nlm.nih.gov/research/pubtator3-api/publications/export/biocjson?pmids={pmid}"
        try_again = True  # Flag to control the retry mechanism
        while try_again:
            response = requests.get(api_url)
            if response.status_code == 200 and response.text.strip():
                # Check if the response is not empty
                try:
                    data = response.json()
                    if data:  # Additional check to ensure JSON is not empty
                        filename = f"{pmid}.json"
                        full_path = os.path.join(base_path, filename)
                        with open(full_path, 'w', encoding='utf-8') as file:
                            json.dump(data, file, indent=4)
                        print(f"Saved full text for PM ID {pmid} in '{full_path}'.")
                        found_count += 1
                    else:
                        print(f"No content for PM ID {pmid}.")
                        not_found_count += 1
                    try_again = False  # No need to retry
                except json.JSONDecodeError:
                    print(f"Failed to decode JSON for PM ID {pmid}.")
                    not_found_count += 1
                    try_again = False  # No need to retry

            elif response.status_code == 429:
                # If HTTP status code is 429, wait for 3 seconds and retry once
                print(f"Rate limit exceeded for PM ID {pmid}. Waiting 3 seconds before retrying...")
                time.sleep(3)  # Wait for 3 seconds
                # After waiting, the loop will try the request again
            else:
                print(f"Failed to fetch full text for PM ID {pmid}: HTTP {response.status_code}")
                not_found_count += 1
                try_again = False  # No need to retry

    print(f"Total articles found and saved: {found_count}")
    print(f"Total articles not found: {not_found_count}")

# %% [markdown]
# #### Full Text

# %%
def fetch_and_save_fulltext_json(pmc_ids_list, base_path, max_articles_to_save):
    """
    Fetches full texts for given PMC IDs in biocjson format and saves them as JSON files in the specified folder.
    Tracks the count of articles not found and successfully retrieved. Stops saving articles once a specified limit is reached.
    
    Parameters:
    - pmcids (list of str): List of PMC IDs.
    - base_path (str): The base directory path where the files will be saved.
    - max_articles_to_save (int): Maximum number of articles to save before ending the function.
    """
    not_found_count = 0
    found_count = 0

    for pmcid in pmc_ids_list:
        if found_count >= max_articles_to_save:
            print(f"Reached the maximum limit of {max_articles_to_save} articles to save.")
            break  # Stop the function if the maximum number of articles to save has been reached

        api_url = f"https://www.ncbi.nlm.nih.gov/research/pubtator3-api/publications/pmc_export/biocjson?pmcids={pmcid}"
        try_again = True  # Flag to control the retry mechanism
        while try_again:
            response = requests.get(api_url)
            if response.status_code == 200 and response.text.strip():
                # Check if the response is not empty
                try:
                    data = response.json()
                    if data:  # Additional check to ensure JSON is not empty
                        filename = f"{pmcid}.json"
                        full_path = os.path.join(base_path, filename)
                        with open(full_path, 'w', encoding='utf-8') as file:
                            json.dump(data, file, indent=4)
                        print(f"Saved full text for PMC ID {pmcid} in '{full_path}'.")
                        found_count += 1
                    else:
                        print(f"No content for PMC ID {pmcid}.")
                        not_found_count += 1
                    try_again = False  # No need to retry
                except json.JSONDecodeError:
                    print(f"Failed to decode JSON for PMC ID {pmcid}.")
                    not_found_count += 1
                    try_again = False  # No need to retry

            elif response.status_code == 429:
                # If HTTP status code is 429, wait for 3 seconds and retry once
                print(f"Rate limit exceeded for PMC ID {pmcid}. Waiting 3 seconds before retrying...")
                time.sleep(3)  # Wait for 3 seconds
                # After waiting, the loop will try the request again
            else:
                print(f"Failed to fetch full text for PMC ID {pmcid}: HTTP {response.status_code}")
                not_found_count += 1
                try_again = False  # No need to retry

    print(f"Total articles found and saved: {found_count}")
    print(f"Total articles not found: {not_found_count}")

# %%
if __name__ == "__main__":
    base_path = "json_files"
    os.makedirs(base_path, exist_ok=True)
    pmids_list = pmids_list
    pmc_ids_list = pmc_ids_list
    max_articles_to_save = 50
    fetch_and_save_abst_json(pmids_list, base_path, max_articles_to_save)
    fetch_and_save_fulltext_json(pmc_ids_list, base_path, max_articles_to_save)
# Out:
# Failed to fetch full text for PM ID 38344818: HTTP 200
# Failed to fetch full text for PM ID 38336101: HTTP 200
# Failed to fetch full text for PM ID 38335412: HTTP 200
# Failed to fetch full text for PM ID 38332651: HTTP 200
# Failed to fetch full text for PM ID 38326178: HTTP 200
# Failed to fetch full text for PM ID 38323371: HTTP 200
# Rate limit exceeded for PM ID 38319780. Waiting 3 seconds before retrying...
# Failed to fetch full text for PM ID 38319780: HTTP 200
# Failed to fetch full text for PM ID 38312689: HTTP 200
# Failed to fetch full text for PM ID 38310012: HTTP 200
# Rate limit exceeded for PM ID 38308541. Waiting 3 seconds before retrying...
# Failed to fetch full text for PM ID 38308541: HTTP 200
# Failed to fetch full text for PM ID 38307830: HTTP 200
# Failed to fetch full text for PM ID 38302294: HTTP 200
# Rate limit exceeded for PM ID 38292987. Waiting 3 seconds before retrying...
# Failed to fetch full text for PM ID 38292987: HTTP 200
# Failed to fetch full text for PM ID 38289232: HTTP 200
# Failed to fetch full text for PM ID 38274968: HTTP 200
# Failed to fetch full text for PM ID 38268013: HTTP 200
# Failed to fetch full text for PM ID 38265339: HTTP 200
# Rate limit exceeded for PM ID 38260726. Waiting 3 seconds before retrying...
# Failed to fetch full text for PM ID 38260726: HTTP 200
# Failed to fetch full text for PM ID 38260320: HTTP 200
# Failed to fetch full text for PM ID 38257151: HTTP 200
# Failed to fetch full text for PM ID 38253605: HTTP 200
# Failed to fetch full text for PM ID 38238015: HTTP 200
# Rate limit exceeded for PM ID 38234649. Waiting 3 seconds before retrying...
# Failed to fetch full text for PM ID 38234649: HTTP 200
# Failed to fetch full text for PM ID 38227982: HTTP 200
# Saved full text for PM ID 38225633 in 'json_files/38225633.json'.
# Rate limit exceeded for PM ID 38215581. Waiting 3 seconds before retrying...
# Saved full text for PM ID 38215581 in 'json_files/38215581.json'.
# Saved full text for PM ID 38215146 in 'json_files/38215146.json'.
# Saved full text for PM ID 38204310 in 'json_files/38204310.json'.
# Saved full text for PM ID 38181478 in 'json_files/38181478.json'.
# Rate limit exceeded for PM ID 38178227. Waiting 3 seconds before retrying...
# Saved full text for PM ID 38178227 in 'json_files/38178227.json'.
# Saved full text for PM ID 38169476 in 'json_files/38169476.json'.
# Saved full text for PM ID 38167227 in 'json_files/38167227.json'.
# Saved full text for PM ID 38161437 in 'json_files/38161437.json'.
# Rate limit exceeded for PM ID 38158354. Waiting 3 seconds before retrying...
# Saved full text for PM ID 38158354 in 'json_files/38158354.json'.
# Saved full text for PM ID 38153527 in 'json_files/38153527.json'.
# Saved full text for PM ID 38150801 in 'json_files/38150801.json'.
# Failed to fetch full text for PM ID 38142410: HTTP 200
# Saved full text for PM ID 38134753 in 'json_files/38134753.json'.
# Rate limit exceeded for PM ID 38132168. Waiting 3 seconds before retrying...
# Saved full text for PM ID 38132168 in 'json_files/38132168.json'.
# Saved full text for PM ID 38128297 in 'json_files/38128297.json'.
# Saved full text for PM ID 38116428 in 'json_files/38116428.json'.
# Saved full text for PM ID 38106733 in 'json_files/38106733.json'.
# Saved full text for PM ID 38089575 in 'json_files/38089575.json'.
# Failed to fetch full text for PM ID 38077792: HTTP 200
# Rate limit exceeded for PM ID 38071276. Waiting 3 seconds before retrying...
# Saved full text for PM ID 38071276 in 'json_files/38071276.json'.
# Saved full text for PM ID 38069808 in 'json_files/38069808.json'.
# Saved full text for PM ID 38069526 in 'json_files/38069526.json'.
# Saved full text for PM ID 38069073 in 'json_files/38069073.json'.
# Saved full text for PM ID 38059298 in 'json_files/38059298.json'.
# Rate limit exceeded for PM ID 38055923. Waiting 3 seconds before retrying...
# Saved full text for PM ID 38055923 in 'json_files/38055923.json'.
# Saved full text for PM ID 38050205 in 'json_files/38050205.json'.
# Saved full text for PM ID 38049244 in 'json_files/38049244.json'.
# Saved full text for PM ID 38049243 in 'json_files/38049243.json'.
# Saved full text for PM ID 38049242 in 'json_files/38049242.json'.
# Rate limit exceeded for PM ID 38046768. Waiting 3 seconds before retrying...
# Saved full text for PM ID 38046768 in 'json_files/38046768.json'.
# Saved full text for PM ID 38046719 in 'json_files/38046719.json'.
# Saved full text for PM ID 38030031 in 'json_files/38030031.json'.
# Saved full text for PM ID 38024620 in 'json_files/38024620.json'.
# Rate limit exceeded for PM ID 38024611. Waiting 3 seconds before retrying...
# Saved full text for PM ID 38024611 in 'json_files/38024611.json'.
# Saved full text for PM ID 38024048 in 'json_files/38024048.json'.
# Saved full text for PM ID 38022077 in 'json_files/38022077.json'.
# Saved full text for PM ID 38021978 in 'json_files/38021978.json'.
# Saved full text for PM ID 38021750 in 'json_files/38021750.json'.
# Saved full text for PM ID 38018175 in 'json_files/38018175.json'.
# Rate limit exceeded for PM ID 38014206. Waiting 3 seconds before retrying...
# Saved full text for PM ID 38014206 in 'json_files/38014206.json'.
# Saved full text for PM ID 38013366 in 'json_files/38013366.json'.
# Saved full text for PM ID 38012683 in 'json_files/38012683.json'.
# Saved full text for PM ID 38010431 in 'json_files/38010431.json'.
# Saved full text for PM ID 38006767 in 'json_files/38006767.json'.
# Saved full text for PM ID 38001830 in 'json_files/38001830.json'.
# Rate limit exceeded for PM ID 37961383. Waiting 3 seconds before retrying...
# Saved full text for PM ID 37961383 in 'json_files/37961383.json'.
# Saved full text for PM ID 37956495 in 'json_files/37956495.json'.
# Saved full text for PM ID 37942183 in 'json_files/37942183.json'.
# Saved full text for PM ID 37941817 in 'json_files/37941817.json'.
# Saved full text for PM ID 37929914 in 'json_files/37929914.json'.
# Rate limit exceeded for PM ID 37917573. Waiting 3 seconds before retrying...
# Saved full text for PM ID 37917573 in 'json_files/37917573.json'.
# Total articles found and saved: 50
# Total articles not found: 26
# Failed to fetch full text for PMC ID PMC10834466: HTTP 200
# Failed to fetch full text for PMC ID PMC10838028: HTTP 200
# Failed to fetch full text for PMC ID PMC10825386: HTTP 200
# Rate limit exceeded for PMC ID PMC10807523. Waiting 3 seconds before retrying...
# Saved full text for PMC ID PMC10807523 in 'json_files/PMC10807523.json'.
# Saved full text for PMC ID PMC10809526 in 'json_files/PMC10809526.json'.
# Failed to fetch full text for PMC ID PMC10802225: HTTP 200
# Failed to fetch full text for PMC ID PMC10800897: HTTP 200
# Failed to fetch full text for PMC ID PMC10802762: HTTP 200
# Failed to fetch full text for PMC ID PMC10820494: HTTP 200
# Rate limit exceeded for PMC ID PMC10803371. Waiting 3 seconds before retrying...
# Saved full text for PMC ID PMC10803371 in 'json_files/PMC10803371.json'.
# Failed to fetch full text for PMC ID PMC10831295: HTTP 200
# Saved full text for PMC ID PMC10793861 in 'json_files/PMC10793861.json'.
# Saved full text for PMC ID PMC10803940 in 'json_files/PMC10803940.json'.
# Saved full text for PMC ID PMC10790401 in 'json_files/PMC10790401.json'.
# Rate limit exceeded for PMC ID PMC10783340. Waiting 3 seconds before retrying...
# Saved full text for PMC ID PMC10783340 in 'json_files/PMC10783340.json'.
# Saved full text for PMC ID PMC10768257 in 'json_files/PMC10768257.json'.
# Saved full text for PMC ID PMC10773620 in 'json_files/PMC10773620.json'.
# Saved full text for PMC ID PMC10755027 in 'json_files/PMC10755027.json'.
# Rate limit exceeded for PMC ID PMC10799142. Waiting 3 seconds before retrying...
# Saved full text for PMC ID PMC10799142 in 'json_files/PMC10799142.json'.
# Saved full text for PMC ID PMC10741507 in 'json_files/PMC10741507.json'.
# Saved full text for PMC ID PMC10725196 in 'json_files/PMC10725196.json'.
# Saved full text for PMC ID PMC10713842 in 'json_files/PMC10713842.json'.
# Failed to fetch full text for PMC ID PMC10710177: HTTP 200
# Failed to fetch full text for PMC ID PMC10706143: HTTP 200
# Rate limit exceeded for PMC ID PMC10820287. Waiting 3 seconds before retrying...
# Saved full text for PMC ID PMC10820287 in 'json_files/PMC10820287.json'.
# Saved full text for PMC ID PMC10695528 in 'json_files/PMC10695528.json'.
# Saved full text for PMC ID PMC10691398 in 'json_files/PMC10691398.json'.
# Saved full text for PMC ID PMC10691739 in 'json_files/PMC10691739.json'.
# Failed to fetch full text for PMC ID PMC10660595: HTTP 200
# Rate limit exceeded for PMC ID PMC10660409. Waiting 3 seconds before retrying...
# Failed to fetch full text for PMC ID PMC10660409: HTTP 200
# Failed to fetch full text for PMC ID PMC10657488: HTTP 200
# Failed to fetch full text for PMC ID PMC10667952: HTTP 200
# Failed to fetch full text for PMC ID PMC10676759: HTTP 200
# Failed to fetch full text for PMC ID PMC10651806: HTTP 200
# Saved full text for PMC ID PMC10680894 in 'json_files/PMC10680894.json'.
# Rate limit exceeded for PMC ID PMC10681612. Waiting 3 seconds before retrying...
# Saved full text for PMC ID PMC10681612 in 'json_files/PMC10681612.json'.
# Saved full text for PMC ID PMC10680200 in 'json_files/PMC10680200.json'.
# Saved full text for PMC ID PMC10669666 in 'json_files/PMC10669666.json'.
# Saved full text for PMC ID PMC10634755 in 'json_files/PMC10634755.json'.
# Saved full text for PMC ID PMC10661604 in 'json_files/PMC10661604.json'.
# Saved full text for PMC ID PMC10628107 in 'json_files/PMC10628107.json'.
# Saved full text for PMC ID PMC10629739 in 'json_files/PMC10629739.json'.
# Saved full text for PMC ID PMC10626592 in 'json_files/PMC10626592.json'.
# Saved full text for PMC ID PMC10632539 in 'json_files/PMC10632539.json'.
# Saved full text for PMC ID PMC10607133 in 'json_files/PMC10607133.json'.
# Saved full text for PMC ID PMC10605810 in 'json_files/PMC10605810.json'.
# Rate limit exceeded for PMC ID PMC10594431. Waiting 3 seconds before retrying...
# Saved full text for PMC ID PMC10594431 in 'json_files/PMC10594431.json'.
# Failed to fetch full text for PMC ID PMC10562566: HTTP 200
# Failed to fetch full text for PMC ID PMC10551275: HTTP 200
# Saved full text for PMC ID PMC10685159 in 'json_files/PMC10685159.json'.
# Saved full text for PMC ID PMC10514847 in 'json_files/PMC10514847.json'.
# Rate limit exceeded for PMC ID PMC10509466. Waiting 3 seconds before retrying...
# Failed to fetch full text for PMC ID PMC10509466: HTTP 200
# Saved full text for PMC ID PMC10685164 in 'json_files/PMC10685164.json'.
# Saved full text for PMC ID PMC10488271 in 'json_files/PMC10488271.json'.
# Saved full text for PMC ID PMC10469705 in 'json_files/PMC10469705.json'.
# Rate limit exceeded for PMC ID PMC10465744. Waiting 3 seconds before retrying...
# Saved full text for PMC ID PMC10465744 in 'json_files/PMC10465744.json'.
# Saved full text for PMC ID PMC10685236 in 'json_files/PMC10685236.json'.
# Failed to fetch full text for PMC ID PMC10448924: HTTP 200
# Failed to fetch full text for PMC ID PMC10448915: HTTP 200
# Rate limit exceeded for PMC ID PMC10435708. Waiting 3 seconds before retrying...
# Saved full text for PMC ID PMC10435708 in 'json_files/PMC10435708.json'.
# Saved full text for PMC ID PMC10435695 in 'json_files/PMC10435695.json'.
# Saved full text for PMC ID PMC10438428 in 'json_files/PMC10438428.json'.
# Failed to fetch full text for PMC ID PMC10427742: HTTP 200
# Saved full text for PMC ID PMC10420352 in 'json_files/PMC10420352.json'.
# Failed to fetch full text for PMC ID PMC10406112: HTTP 200
# Saved full text for PMC ID PMC10409856 in 'json_files/PMC10409856.json'.
# Failed to fetch full text for PMC ID PMC10370499: HTTP 200
# Rate limit exceeded for PMC ID PMC10366386. Waiting 3 seconds before retrying...
# Failed to fetch full text for PMC ID PMC10366386: HTTP 200
# Failed to fetch full text for PMC ID PMC10332774: HTTP 200
# Saved full text for PMC ID PMC10501344 in 'json_files/PMC10501344.json'.
# Saved full text for PMC ID PMC10635957 in 'json_files/PMC10635957.json'.
# Failed to fetch full text for PMC ID PMC10350163: HTTP 200
# Failed to fetch full text for PMC ID PMC10348089: HTTP 200
# Rate limit exceeded for PMC ID PMC10343943. Waiting 3 seconds before retrying...
# Failed to fetch full text for PMC ID PMC10343943: HTTP 200
# Saved full text for PMC ID PMC10582275 in 'json_files/PMC10582275.json'.
# Saved full text for PMC ID PMC10685147 in 'json_files/PMC10685147.json'.
# Failed to fetch full text for PMC ID PMC10318122: HTTP 200
# Failed to fetch full text for PMC ID PMC10315176: HTTP 200
# Failed to fetch full text for PMC ID PMC10308803: HTTP 200
# Rate limit exceeded for PMC ID PMC10301107. Waiting 3 seconds before retrying...
# Saved full text for PMC ID PMC10301107 in 'json_files/PMC10301107.json'.
# Saved full text for PMC ID PMC10303389 in 'json_files/PMC10303389.json'.
# Saved full text for PMC ID PMC10267409 in 'json_files/PMC10267409.json'.
# Reached the maximum limit of 50 articles to save.
# Total articles found and saved: 50
# Total articles not found: 32
