# %%
import os
import json
import pandas as pd

# %% [markdown]
# ## Part I: Analyse Automaxo results

# %%
def extract_data(base_path: str):
    """
    Extract raw triplet rows and disease-level info from TSV/JSON files.
    Returns:
        full_df (pd.DataFrame): one row per triplet
        disease_info (dict): per-disease counts and PubMed ID sets
    """
    rows = []
    disease_info = {}

    for disease in os.listdir(base_path):
        folder = os.path.join(base_path, disease)
        if not os.path.isdir(folder):
            continue

        # Count initial and filtered PubMed IDs
        initial = filtered = 0
        for fn in os.listdir(folder):
            path = os.path.join(folder, fn)
            if fn.endswith('_no_replaced.tsv'):
                initial = sum(1 for _ in open(path)) - 1
            if fn.endswith('_filtered.tsv'):
                filtered = sum(1 for _ in open(path)) - 1

        # Load JSON triplets
        json_path = os.path.join(folder, 'final_automaxo_results.json')
        if not os.path.exists(json_path):
            continue
        data = json.load(open(json_path))

        info = disease_info.setdefault(disease, {
            'initial_pubmed_count': initial,
            'filtered_pubmed_count': filtered,
            'triplet_count': 0,
            'unique_pubmed_ids': set()
        })

        for entry in data.get('triplets', []):
            t = entry['triplet']
            sources = entry.get('source', {})

            info['unique_pubmed_ids'].update(sources.keys())
            info['triplet_count'] += 1

            rows.append({
                'disease': disease,
                'maxo': t.get('maxo'),
                'hpo': t.get('hpo'),
                'mondo': t.get('mondo'),
                'non_grounded_maxo': t.get('non_grounded_maxo'),
                'non_grounded_hpo': t.get('non_grounded_hpo'),
                'non_grounded_mondo': t.get('non_grounded_mondo'),
                'potential_maxo': t.get('potential_maxo', []),
                'potential_hpo': t.get('potential_hpo', []),
                'potential_mondo': t.get('potential_mondo', []),
                'no_of_titles': sum(1 for d in sources.values() if 'title' in d),
                'no_of_abstracts': sum(1 for d in sources.values() if 'abstract' in d)
            })

    full_df = pd.DataFrame(rows)
    return full_df, disease_info

def clean_data(full_df: pd.DataFrame):
    """
    Replace literal "None" strings with actual NA values.
    """
    cols_to_clean = [
        'maxo', 'hpo', 'mondo',
        'non_grounded_maxo', 'non_grounded_hpo', 'non_grounded_mondo'
    ]
    for col in cols_to_clean:
        full_df[col] = full_df[col].replace("None", pd.NA)
    return full_df

def summarize_data(full_df: pd.DataFrame, disease_info: dict):
    """
    Summarize metrics per disease based on the cleaned full_df and disease_info.
    Returns:
        summary_df (pd.DataFrame): one row per disease with all metrics
    """
    def count_potential(sub, col):
        ids = set()
        for lst in sub[col].dropna():
            for item in lst:
                if isinstance(item, dict) and 'id' in item:
                    ids.add(item['id'])
                elif isinstance(item, str):
                    ids.add(item)
        return len(ids)

    summary_rows = []
    for disease, info in disease_info.items():
        sub = full_df[full_df['disease'] == disease]
        total_titles = sub['no_of_titles'].sum()
        total_abstracts = sub['no_of_abstracts'].sum()

        unique_maxo = sub['maxo'].nunique(dropna=True)
        total_maxo = sub['maxo'].count()
        unique_hpo = sub['hpo'].nunique(dropna=True)
        total_hpo = sub['hpo'].count()
        unique_mondo = sub['mondo'].nunique(dropna=True)
        total_mondo = sub['mondo'].count()

        ng_maxo = sub['non_grounded_maxo'].notna().sum()
        ng_hpo = sub['non_grounded_hpo'].notna().sum()
        ng_mondo = sub['non_grounded_mondo'].notna().sum()
        total_non_grounded = ng_maxo + ng_hpo + ng_mondo

        pot_maxo = count_potential(sub, 'potential_maxo')
        pot_hpo = count_potential(sub, 'potential_hpo')
        pot_mondo = count_potential(sub, 'potential_mondo')
        total_potential = pot_maxo + pot_hpo + pot_mondo

        summary_rows.append({
            'Disease': disease,
            'initial_pubmed_count': info['initial_pubmed_count'],
            'filtered_pubmed_count': info['filtered_pubmed_count'],
            'unique_pubmed_ids': len(info['unique_pubmed_ids']),
            'triplet_count': info['triplet_count'],
            'total_titles': total_titles,
            'total_abstracts': total_abstracts,
            'unique_maxo': unique_maxo,
            'total_maxo': total_maxo,
            'unique_hpo': unique_hpo,
            'total_hpo': total_hpo,
            'unique_mondo': unique_mondo,
            'total_mondo': total_mondo,
            'total_non_grounded': total_non_grounded,
            'non_grounded_maxo': ng_maxo,
            'non_grounded_hpo': ng_hpo,
            'non_grounded_mondo': ng_mondo,
            'total_potential': total_potential,
            'potential_maxo': pot_maxo,
            'potential_hpo': pot_hpo,
            'potential_mondo': pot_mondo
        })

    return pd.DataFrame(summary_rows)

# %%
base_path = '../data'
full_disease_analysis_df, disease_info = extract_data(base_path)
full_disease_analysis_df = clean_data(full_disease_analysis_df)
disease_summary_automaxo = summarize_data(full_disease_analysis_df, disease_info)

# %%
disease_summary_automaxo
# Out:
#                          Disease  initial_pubmed_count  filtered_pubmed_count  \
# 0                dravet_syndrome                    99                     78
# 1   familial_mediterranean_fever                   100                     84
# 2           loeys_dietz_syndrome                    35                     34
# 3         donnai-barrow_syndrome                     3                      3
# 4     primary_ciliary_dyskinesia                    98                     76
# 5             camurati_engelmann                    14                     12
# 6                    sickle_cell                  2000                    990
# 7                gaucher_disease                    99                     88
# 8                 celiac_disease                  2000                   1240
# 9                canavan_disease                    39                     20
# 10                milroy_disease                     2                      2
# 11      chediak_higashi_syndrome                    48                     46
# 12            propionic_acidemia                    50                     42
# 13             hypochondroplasia                    13                     13
# 14                      leukemia                    81                     56
# 15               marfan_syndrome                   150                    132
# 16            huntington_disease                   226                    110
# 17                apert_syndrome                    50                     42
# 18                 rett_syndrome                   100                     48
# 19                 citrullinemia                    50                     45
# 20              brugada_syndrome                    27                     25
# 21                wilson_disease                   252                    230
# 22       spinal_muscular_atrophy                    98                     84
# 23            tuberous_sclerosis                    98                     84
# 24          lesch_nyhan_syndrome                    50                     37
# 25     maple_syrup_urine_disease                    99                     83
# 26  mucopolysaccharidosis_type_i                   100                     65
# 27                fanconi_anemia                   100                     71
# 28         ataxia_telangiectasia                   100                     43
# 29               noonan_syndrome                   129                    120
# 30                  alkaptonuria                    42                     40
# 31             stickler_syndrome                    28                     26
#
#     unique_pubmed_ids  triplet_count  total_titles  total_abstracts  \
# 0                  77            342           344              344
# 1                  80            377           377              377
# 2                  33            139           144              144
# 3                   3             20            20               20
# 4                  72            325           325              325
# 5                  11             34            34               34
# 6                 958           3829          3917             3917
# 7                  87            365           368              368
# 8                1165           4718          4878             4878
# 9                  20             76            76               76
# 10                  2             15            15               15
# 11                 40            167           167              167
# 12                 40            161           162              162
# 13                 13             41            41               41
# 14                 54            264           264              264
# 15                125            507           507              507
# 16                106            463           463              463
# 17                 40            196           197              197
# 18                 46            176           176              176
# 19                 42            180           182              182
# 20                 24             73            73               73
# 21                214            963           989              989
# 22                 82            355           356              356
# 23                 81            329           332              332
# 24                 33            111           111              111
# 25                 78            321           323              323
# 26                 64            289           290              290
# 27                 71            289           296              296
# 28                 43            204           204              204
# 29                107            400           401              401
# 30                 33            111           112              112
# 31                 24            100           100              100
#
#     unique_maxo  total_maxo  unique_hpo  ...  unique_mondo  total_mondo  \
# 0            12          41          26  ...             8          239
# 1            13          33          42  ...            22          323
# 2            12          18          19  ...             2           85
# 3             8           8           5  ...             1           13
# 4            18          31          29  ...            12          244
# 5             3           6           9  ...             2           28
# 6            65         452         144  ...            55         2466
# 7            14          42          45  ...            10          244
# 8            67         313         219  ...            90         2846
# 9             4          13           5  ...             8           45
# 10            2           5           1  ...             1           15
# 11            9          27          21  ...             7           92
# 12            4          41          13  ...             8           93
# 13            6           9           5  ...             6           26
# 14           14          32          25  ...            17          134
# 15           18          30          57  ...            14          229
# 16           16          29          35  ...            18          343
# 17           16          31          24  ...             5          130
# 18           13          25          11  ...            10          111
# 19            7          51          19  ...            12          142
# 20            5           8          14  ...             5           42
# 21           20         154          85  ...            29          628
# 22           10          42          25  ...            11          226
# 23           18          33          39  ...            20          230
# 24           11          31          21  ...             1           75
# 25            9          68          37  ...            15          231
# 26           11          55          41  ...            10          229
# 27           16          59          22  ...            10          163
# 28           11          30          20  ...            10          101
# 29           23          51          61  ...            38          261
# 30            7           9          10  ...             4           72
# 31            7          12          12  ...             9           79
#
#     total_non_grounded  non_grounded_maxo  non_grounded_hpo  \
# 0                  605                301               201
# 1                  685                344               287
# 2                  271                121                96
# 3                   27                 12                 8
# 4                  634                294               259
# 5                   54                 28                20
# 6                 7899               3377              3159
# 7                  710                323               266
# 8                 9917               4405              3640
# 9                  162                 63                68
# 10                  22                 10                12
# 11                 351                140               136
# 12                 312                120               124
# 13                  80                 32                33
# 14                 561                232               199
# 15                1124                477               369
# 16                 912                434               358
# 17                 385                165               154
# 18                 371                151               155
# 19                 302                129               135
# 20                 143                 65                47
# 21                1876                809               732
# 22                 685                313               243
# 23                 605                296               210
# 24                 193                 80                77
# 25                 610                253               267
# 26                 516                234               222
# 27                 598                230               242
# 28                 433                174               156
# 29                 777                349               289
# 30                 235                102                94
# 31                 156                 88                47
#
#     non_grounded_mondo  total_potential  potential_maxo  potential_hpo  \
# 0                  103                9               1              4
# 1                   54               12               1              4
# 2                   54                4               1              1
# 3                    7                2               0              1
# 4                   81               20               5             12
# 5                    6                4               1              2
# 6                 1363              102              25             51
# 7                  121               11               4              2
# 8                 1872              158              20             96
# 9                   31                4               1              0
# 10                   0                0               0              0
# 11                  75               13               5              5
# 12                  68               12               2              6
# 13                  15                1               1              0
# 14                 130               18               4              5
# 15                 278               23               4             10
# 16                 120               22               7             10
# 17                  66               10               3              4
# 18                  65                7               3              2
# 19                  38               11               1              5
# 20                  31                8               1              5
# 21                 335               33              10             14
# 22                 129               16               2             11
# 23                  99               15               3              7
# 24                  36               10               4              5
# 25                  90               10               5              2
# 26                  60               13               4              4
# 27                 126               25               8              6
# 28                 103               14               3              4
# 29                 139               25               2             11
# 30                  39                4               1              1
# 31                  21               13               4              6
#
#     potential_mondo
# 0                 4
# 1                 7
# 2                 2
# 3                 1
# 4                 3
# 5                 1
# 6                26
# 7                 5
# 8                42
# 9                 3
# 10                0
# 11                3
# 12                4
# 13                0
# 14                9
# 15                9
# 16                5
# 17                3
# 18                2
# 19                5
# 20                2
# 21                9
# 22                3
# 23                5
# 24                1
# 25                3
# 26                5
# 27               11
# 28                7
# 29               12
# 30                2
# 31                3
#
# [32 rows x 21 columns]

# %%
full_disease_analysis_df
# Out:
#                  disease          maxo         hpo          mondo  \
# 0        dravet_syndrome          <NA>        <NA>           <NA>
# 1        dravet_syndrome          <NA>  hp:0001250  mondo:0100135
# 2        dravet_syndrome          <NA>        <NA>           <NA>
# 3        dravet_syndrome          <NA>        <NA>           <NA>
# 4        dravet_syndrome          <NA>        <NA>           <NA>
# ...                  ...           ...         ...            ...
# 15935  stickler_syndrome  maxo:0000571        <NA>  mondo:0019354
# 15936  stickler_syndrome  maxo:0000571  hp:0000689  mondo:0009869
# 15937  stickler_syndrome  maxo:0001085  hp:0012230  mondo:0019354
# 15938  stickler_syndrome  maxo:0009072  hp:0000541           <NA>
# 15939  stickler_syndrome  maxo:0009072  hp:0007663  mondo:0008375
#
#                                    non_grounded_maxo  \
# 0                                     add-on therapy
# 1                                 use of cannabidiol
# 2      access to syndrome-specific treatment options
# 3                       add-on stiripentol treatment
# 4                                     add-on therapy
# ...                                              ...
# 15935                                           <NA>
# 15936                                           <NA>
# 15937                                           <NA>
# 15938                                           <NA>
# 15939                                           <NA>
#
#                        non_grounded_hpo                    non_grounded_mondo  \
# 0                     seizure frequency         drug-resistant focal epilepsy
# 1                                  <NA>                                  <NA>
# 2                         mismanagement                       dravet syndrome
# 3                     seizure frequency                 refractory epilepsies
# 4      gastrointestinal adverse effects         drug-resistant focal epilepsy
# ...                                 ...                                   ...
# 15935               open-bite deformity                                  <NA>
# 15936                              <NA>                                  <NA>
# 15937                              <NA>                                  <NA>
# 15938                              <NA>  chronic pediatric retinal detachment
# 15939                              <NA>                                  <NA>
#
#       potential_maxo potential_hpo  \
# 0                 []            []
# 1                 []            []
# 2                 []            []
# 3                 []            []
# 4                 []            []
# ...              ...           ...
# 15935             []            []
# 15936             []            []
# 15937             []            []
# 15938             []            []
# 15939             []            []
#
#                                          potential_mondo  no_of_titles  \
# 0                                                     []             2
# 1                                                     []             2
# 2      [{'id': 'MONDO:0100135', 'label': 'Dravet synd...             1
# 3                                                     []             1
# 4                                                     []             1
# ...                                                  ...           ...
# 15935                                                 []             1
# 15936                                                 []             1
# 15937                                                 []             1
# 15938                                                 []             1
# 15939                                                 []             1
#
#        no_of_abstracts
# 0                    2
# 1                    2
# 2                    1
# 3                    1
# 4                    1
# ...                ...
# 15935                1
# 15936                1
# 15937                1
# 15938                1
# 15939                1
#
# [15940 rows x 12 columns]

# %% [markdown]
# ## Part II: Analyse Automaxoviewer results aka final expert curation

# %%
import os
import glob
import pandas as pd

# Folder containing the TSV files
folder_path = 'maxo_final_curation'

# Expected core columns
expected_cols = [
    'disease_id', 'disease_name', 'source_id', 'maxo_id', 'maxo_name',
    'hpo_id', 'relation', 'evidence', 'extension_id', 'extension_name',
    'comment', 'other', 'author', 'last_updated', 'created'
]

dfs = []
for file_path in glob.glob(os.path.join(folder_path, '*.tsv')):
    # Read TSV
    df = pd.read_csv(file_path, sep='\t', dtype=str)
    # Strip whitespace from headers
    df.columns = df.columns.str.strip()
    
    # If any combined headers (e.g., 'author last_updated'), split them
    if 'author last_updated' in df.columns:
        df[['author', 'last_updated']] = df['author last_updated'].str.split(n=1, expand=True)
        df = df.drop(columns=['author last_updated'])
    
    # Ensure all expected columns exist
    for col in expected_cols:
        if col not in df.columns:
            df[col] = pd.NA
    
    # Keep only expected columns + file_name
    df = df[expected_cols]
    df['file_name'] = os.path.basename(file_path)
    
    dfs.append(df)

# Concatenate and drop any duplicate columns
maxo_final_curation_df = pd.concat(dfs, ignore_index=True)
maxo_final_curation_df = maxo_final_curation_df.loc[:, ~maxo_final_curation_df.columns.duplicated()]

# %%
maxo_final_curation_df
# Out:
#         disease_id          disease_name      source_id       maxo_id  \
# 0    MONDO:0010726         Rett syndrome  PMID:29587149  MAXO:0000944
# 1    MONDO:0010726         Rett syndrome  PMID:29941161  MAXO:0001346
# 2    MONDO:0010726         Rett syndrome  PMID:31469772  MAXO:0000667
# 3    MONDO:0010726         Rett syndrome  PMID:31568388  MAXO:0000465
# 4    MONDO:0010726         Rett syndrome  PMID:34282992  MAXO:0000011
# ..             ...                   ...            ...           ...
# 953  MONDO:0018954  Loeys-Dietz syndrome  PMID:29889773  MAXO:0000479
# 954  MONDO:0018954  Loeys-Dietz syndrome  PMID:30513314  MAXO:0010032
# 955  MONDO:0018954  Loeys-Dietz syndrome  PMID:31842932  MAXO:0035065
# 956  MONDO:0018954  Loeys-Dietz syndrome  PMID:32164578  MAXO:0001346
# 957  MONDO:0018954  Loeys-Dietz syndrome  PMID:35095068  MAXO:0001281
#
#                                 maxo_name      hpo_id relation evidence  \
# 0          cranial electrical stimulation  HP:0000118   treats      PCS
# 1                             gastrostomy  HP:0004325  unknown      PCS
# 2    anesthesiology specialist evaluation  HP:0000118   treats      PCS
# 3                aquatic exercise therapy  HP:0000118   treats      PCS
# 4                        physical therapy  HP:0000118   treats      PCS
# ..                                    ...         ...      ...      ...
# 953                    orthopedic surgery  HP:0003302   treats      PCS
# 954               cardiac transplantation  HP:0001635   treats      PCS
# 955                    dentist evaluation  HP:0000118   treats      PCS
# 956                           gastrostomy  HP:0001508   treats      PCS
# 957              surgical repair of aorta  HP:0012727   treats      PCS
#
#     extension_id extension_name comment other               author  \
# 0            NaN            NaN     NaN   NaN  0000-0002-0736-9199
# 1            NaN            NaN     NaN   NaN  0000-0002-0736-9199
# 2            NaN            NaN     NaN   NaN  0000-0002-0736-9199
# 3            NaN            NaN     NaN   NaN  0000-0002-0736-9199
# 4            NaN            NaN     NaN   NaN  0000-0002-0736-9199
# ..           ...            ...     ...   ...                  ...
# 953          NaN            NaN     NaN   NaN  0000-0002-0736-9199
# 954          NaN            NaN     NaN   NaN  0000-0002-0736-9199
# 955          NaN            NaN     NaN   NaN  0000-0002-0736-9199
# 956          NaN            NaN     NaN   NaN  0000-0002-0736-9199
# 957          NaN            NaN     NaN   NaN  0000-0002-0736-9199
#
#     last_updated     created      file_name
# 0            NaN  2025-05-10  maxo_Rett.tsv
# 1            NaN  2025-05-10  maxo_Rett.tsv
# 2            NaN  2025-05-10  maxo_Rett.tsv
# 3            NaN  2025-05-10  maxo_Rett.tsv
# 4            NaN  2025-05-10  maxo_Rett.tsv
# ..           ...         ...            ...
# 953          NaN  2024-08-02   maxo_LDS.tsv
# 954          NaN  2024-08-02   maxo_LDS.tsv
# 955          NaN  2024-08-02   maxo_LDS.tsv
# 956          NaN  2024-08-02   maxo_LDS.tsv
# 957          NaN  2024-08-02   maxo_LDS.tsv
#
# [958 rows x 16 columns]

# %%
maxo_final_curation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 958 entries, 0 to 957
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   disease_id      958 non-null    object
#  1   disease_name    958 non-null    object
#  2   source_id       958 non-null    object
#  3   maxo_id         958 non-null    object
#  4   maxo_name       958 non-null    object
#  5   hpo_id          958 non-null    object
#  6   relation        958 non-null    object
#  7   evidence        958 non-null    object
#  8   extension_id    57 non-null     object
#  9   extension_name  57 non-null     object
#  10  comment         0 non-null      object
#  11  other           0 non-null      object
#  12  author          958 non-null    object
#  13  last_updated    0 non-null      object
#  14  created         958 non-null    object
#  15  file_name       958 non-null    object
# dtypes: object(16)
# memory usage: 119.9+ KB

# %%
import pandas as pd

# Build summary DataFrame with total_annotations per disease
summary_curation = (
    maxo_final_curation_df
      .groupby(['disease_id', 'disease_name', 'file_name'], dropna=False)
      .agg(
          maxo_id_count_curated       = ('maxo_id',      'nunique'),
          hpo_id_count_curated       = ('hpo_id',       'nunique'),
          relation_count_curated      = ('relation',     'nunique'),
          total_annotations_curated   = ('disease_id',   'size'),
      )
      .reset_index()
)

# %%
summary_curation
# Out:
#        disease_id                         disease_name  \
# 0   MONDO:0001516              spinal muscular atrophy
# 1   MONDO:0001586         mucopolysaccharidosis type 1
# 2   MONDO:0001734                   tuberous sclerosis
# 3   MONDO:0005130                       celiac disease
# 4   MONDO:0007037                       Achondroplasia
# 5   MONDO:0007041                       Apert syndrome
# 6   MONDO:0007542           Camurati-Engelmann disease
# 7   MONDO:0007739                   Huntington disease
# 8   MONDO:0007793                    hypochondroplasia
# 9   MONDO:0007919             lymphatic malformation 1
# 10  MONDO:0007919             lymphatic malformation 1
# 11  MONDO:0007947                      Marfan syndrome
# 12  MONDO:0008753                         alkaptonuria
# 13  MONDO:0008840                ataxia telangiectasia
# 14  MONDO:0008963             Chediak-Higashi syndrome
# 15  MONDO:0009104               Donnai-Barrow syndrome
# 16  MONDO:0009266              Gaucher disease type II
# 17  MONDO:0009267             Gaucher disease type III
# 18  MONDO:0009563            maple syrup urine disease
# 19  MONDO:0009669      spinal muscular atrophy, type 1
# 20  MONDO:0009672    spinal muscular atrophy, type III
# 21  MONDO:0009673     spinal muscular atrophy, type II
# 22  MONDO:0010079                      Canavan disease
# 23  MONDO:0010200                       Wilson disease
# 24  MONDO:0010298                 Lesch-Nyhan syndrome
# 25  MONDO:0010726                        Rett syndrome
# 26  MONDO:0011326  citrullinemia, type II, adult-onset
# 27  MONDO:0011382                   sickle cell anemia
# 28  MONDO:0011628                   propionic acidemia
# 29  MONDO:0015263                     Brugada syndrome
# 30  MONDO:0016575           primary ciliary dyskinesia
# 31  MONDO:0018088         familial Mediterranean fever
# 32  MONDO:0018150                      Gaucher disease
# 33  MONDO:0018954                 Loeys-Dietz syndrome
# 34  MONDO:0018997                      Noonan syndrome
# 35  MONDO:0019354                    Stickler syndrome
# 36  MONDO:0019391                       Fanconi anemia
# 37  MONDO:0100135                      Dravet syndrome
#
#                     file_name  maxo_id_count_curated  hpo_id_count_curated  \
# 0                maxo_SMA.tsv                      6                     4
# 1               maxo_MPS1.tsv                      7                    13
# 2                 maxo_TS.tsv                     15                    12
# 3             maxo_Celiac.tsv                      1                     8
# 4             maxo_hypoch.tsv                      1                     1
# 5              maxo_Apert.tsv                     11                    15
# 6   maxo_CamuratiEngelman.tsv                      7                     5
# 7         maxo_Huntington.tsv                     22                    16
# 8             maxo_hypoch.tsv                      3                     3
# 9             maxo_Milroy.tsv                      1                     1
# 10          maxo_milroy 2.tsv                      2                     2
# 11               maxo_MFS.tsv                     17                    18
# 12           maxo_Alkapto.tsv                      7                     6
# 13        maxo_ataxia_tel.tsv                      8                     5
# 14           maxo_Chediak.tsv                      3                     2
# 15      maxo_DonnaiBarrow.tsv                      7                     8
# 16           maxo_Gaucher.tsv                      1                     1
# 17           maxo_Gaucher.tsv                      3                     3
# 18       maxo_maple_syrup.tsv                     10                     3
# 19               maxo_SMA.tsv                      2                     1
# 20               maxo_SMA.tsv                      2                     2
# 21               maxo_SMA.tsv                      1                     1
# 22           maxo_Canavan.tsv                      4                     4
# 23            maxo_Wilson.tsv                      9                    16
# 24               maxo_LNS.tsv                      9                     9
# 25              maxo_Rett.tsv                      9                     3
# 26     maxo_Citrullinemia.tsv                      5                     3
# 27        maxo_SickleCell.tsv                     31                    21
# 28              maxo_prop.tsv                      8                     4
# 29           maxo_Brugada.tsv                      3                     6
# 30               maxo_PCD.tsv                     13                     8
# 31               maxo_FMF.tsv                      9                     5
# 32           maxo_Gaucher.tsv                      8                     6
# 33               maxo_LDS.tsv                     11                    15
# 34            maxo_Noonan.tsv                     17                    22
# 35          maxo_Stickler.tsv                      6                     5
# 36           maxo_Fanconi.tsv                     10                     8
# 37            maxo_dravet.tsv                      5                     4
#
#     relation_count_curated  total_annotations_curated
# 0                        2                         39
# 1                        4                         48
# 2                        3                         35
# 3                        2                         67
# 4                        2                          2
# 5                        3                         24
# 6                        3                         10
# 7                        3                         46
# 8                        2                          4
# 9                        1                          1
# 10                       1                          2
# 11                       2                         44
# 12                       2                         13
# 13                       2                         10
# 14                       2                         17
# 15                       2                          8
# 16                       1                          3
# 17                       2                          6
# 18                       3                         53
# 19                       2                          2
# 20                       2                          2
# 21                       1                          1
# 22                       2                          8
# 23                       4                         48
# 24                       2                         21
# 25                       3                         12
# 26                       3                         14
# 27                       4                        117
# 28                       2                         22
# 29                       2                         10
# 30                       3                         24
# 31                       3                         36
# 32                       3                         48
# 33                       2                         20
# 34                       1                         31
# 35                       2                         11
# 36                       3                         53
# 37                       3                         46

# %%
import pandas as pd
# Copy original DataFrames
df1 = summary_curation.copy()
df2 = disease_summary_automaxo.copy()

# 1. Create a base key from the file_name in df1
df1['base_key'] = (
    df1['file_name']
       .str.lower()
       .str.removeprefix('maxo_')
       .str.removesuffix('.tsv')
       .str.replace(r'[_\-\s]', '', regex=True)
)

# 2. Define mapping from base_key (Format A) to Disease codes (Format B)
mapping = {
    'rett': 'rett_syndrome',
    'wilson': 'wilson_disease',
    'maplesyrup': 'maple_syrup_urine_disease',
    'donnaibarrow': 'donnai-barrow_syndrome',
    'camuratiefengelmann': 'camurati_engelmann',
    'ts': 'tuberous_sclerosis',
    'apert': 'apert_syndrome',
    'prop': 'propionic_acidemia',
    'ataxiatel': 'ataxia_telangiectasia',
    'sma': 'spinal_muscular_atrophy',
    'mps1': 'mucopolysaccharidosis_type_i',
    'mfs': 'marfan_syndrome',
    'citrullinemia': 'citrullinemia',
    'noonan': 'noonan_syndrome',
    'fmf': 'familial_mediterranean_fever',
    'celiac': 'celiac_disease',
    'milroy': 'milroy_disease',
    'milroy2': 'milroy_disease',
    'brugada': 'brugada_syndrome',
    'dravet': 'dravet_syndrome',
    'stickler': 'stickler_syndrome',
    'lns': 'lesch_nyhan_syndrome',
    'canavan': 'canavan_disease',
    'fanconi': 'fanconi_anemia',
    'hypoch': 'hypochondroplasia',
    'huntington': 'huntington_disease',
    'pcd': 'primary_ciliary_dyskinesia',
    'alkapto': 'alkaptonuria',
    'sicklecell': 'sickle_cell',
    'chediak': 'chediak_higashi_syndrome',
    'gaucher': 'gaucher_disease',
    'lds': 'loeys_dietz_syndrome'
}

# 3. Map base_key to the Format B disease names
df1['Disease'] = df1['base_key'].map(mapping)

# 4. Merge the two DataFrames on the standardized Disease column
merged_curation_automaxo_df = pd.merge(
    df1,
    df2,
    on='Disease',
    how='inner',
    suffixes=('_curated', '_automaxo')
)

# %%
# Display merged result
merged_curation_automaxo_df
# Out:
#        disease_id                         disease_name  \
# 0   MONDO:0001516              spinal muscular atrophy
# 1   MONDO:0001586         mucopolysaccharidosis type 1
# 2   MONDO:0001734                   tuberous sclerosis
# 3   MONDO:0005130                       celiac disease
# 4   MONDO:0007037                       Achondroplasia
# 5   MONDO:0007041                       Apert syndrome
# 6   MONDO:0007739                   Huntington disease
# 7   MONDO:0007793                    hypochondroplasia
# 8   MONDO:0007919             lymphatic malformation 1
# 9   MONDO:0007919             lymphatic malformation 1
# 10  MONDO:0007947                      Marfan syndrome
# 11  MONDO:0008753                         alkaptonuria
# 12  MONDO:0008840                ataxia telangiectasia
# 13  MONDO:0008963             Chediak-Higashi syndrome
# 14  MONDO:0009104               Donnai-Barrow syndrome
# 15  MONDO:0009266              Gaucher disease type II
# 16  MONDO:0009267             Gaucher disease type III
# 17  MONDO:0009563            maple syrup urine disease
# 18  MONDO:0009669      spinal muscular atrophy, type 1
# 19  MONDO:0009672    spinal muscular atrophy, type III
# 20  MONDO:0009673     spinal muscular atrophy, type II
# 21  MONDO:0010079                      Canavan disease
# 22  MONDO:0010200                       Wilson disease
# 23  MONDO:0010298                 Lesch-Nyhan syndrome
# 24  MONDO:0010726                        Rett syndrome
# 25  MONDO:0011326  citrullinemia, type II, adult-onset
# 26  MONDO:0011382                   sickle cell anemia
# 27  MONDO:0011628                   propionic acidemia
# 28  MONDO:0015263                     Brugada syndrome
# 29  MONDO:0016575           primary ciliary dyskinesia
# 30  MONDO:0018088         familial Mediterranean fever
# 31  MONDO:0018150                      Gaucher disease
# 32  MONDO:0018954                 Loeys-Dietz syndrome
# 33  MONDO:0018997                      Noonan syndrome
# 34  MONDO:0019354                    Stickler syndrome
# 35  MONDO:0019391                       Fanconi anemia
# 36  MONDO:0100135                      Dravet syndrome
#
#                  file_name  maxo_id_count_curated  hpo_id_count_curated  \
# 0             maxo_SMA.tsv                      6                     4
# 1            maxo_MPS1.tsv                      7                    13
# 2              maxo_TS.tsv                     15                    12
# 3          maxo_Celiac.tsv                      1                     8
# 4          maxo_hypoch.tsv                      1                     1
# 5           maxo_Apert.tsv                     11                    15
# 6      maxo_Huntington.tsv                     22                    16
# 7          maxo_hypoch.tsv                      3                     3
# 8          maxo_Milroy.tsv                      1                     1
# 9        maxo_milroy 2.tsv                      2                     2
# 10            maxo_MFS.tsv                     17                    18
# 11        maxo_Alkapto.tsv                      7                     6
# 12     maxo_ataxia_tel.tsv                      8                     5
# 13        maxo_Chediak.tsv                      3                     2
# 14   maxo_DonnaiBarrow.tsv                      7                     8
# 15        maxo_Gaucher.tsv                      1                     1
# 16        maxo_Gaucher.tsv                      3                     3
# 17    maxo_maple_syrup.tsv                     10                     3
# 18            maxo_SMA.tsv                      2                     1
# 19            maxo_SMA.tsv                      2                     2
# 20            maxo_SMA.tsv                      1                     1
# 21        maxo_Canavan.tsv                      4                     4
# 22         maxo_Wilson.tsv                      9                    16
# 23            maxo_LNS.tsv                      9                     9
# 24           maxo_Rett.tsv                      9                     3
# 25  maxo_Citrullinemia.tsv                      5                     3
# 26     maxo_SickleCell.tsv                     31                    21
# 27           maxo_prop.tsv                      8                     4
# 28        maxo_Brugada.tsv                      3                     6
# 29            maxo_PCD.tsv                     13                     8
# 30            maxo_FMF.tsv                      9                     5
# 31        maxo_Gaucher.tsv                      8                     6
# 32            maxo_LDS.tsv                     11                    15
# 33         maxo_Noonan.tsv                     17                    22
# 34       maxo_Stickler.tsv                      6                     5
# 35        maxo_Fanconi.tsv                     10                     8
# 36         maxo_dravet.tsv                      5                     4
#
#     relation_count_curated  total_annotations_curated       base_key  \
# 0                        2                         39            sma
# 1                        4                         48           mps1
# 2                        3                         35             ts
# 3                        2                         67         celiac
# 4                        2                          2         hypoch
# 5                        3                         24          apert
# 6                        3                         46     huntington
# 7                        2                          4         hypoch
# 8                        1                          1         milroy
# 9                        1                          2        milroy2
# 10                       2                         44            mfs
# 11                       2                         13        alkapto
# 12                       2                         10      ataxiatel
# 13                       2                         17        chediak
# 14                       2                          8   donnaibarrow
# 15                       1                          3        gaucher
# 16                       2                          6        gaucher
# 17                       3                         53     maplesyrup
# 18                       2                          2            sma
# 19                       2                          2            sma
# 20                       1                          1            sma
# 21                       2                          8        canavan
# 22                       4                         48         wilson
# 23                       2                         21            lns
# 24                       3                         12           rett
# 25                       3                         14  citrullinemia
# 26                       4                        117     sicklecell
# 27                       2                         22           prop
# 28                       2                         10        brugada
# 29                       3                         24            pcd
# 30                       3                         36            fmf
# 31                       3                         48        gaucher
# 32                       2                         20            lds
# 33                       1                         31         noonan
# 34                       2                         11       stickler
# 35                       3                         53        fanconi
# 36                       3                         46         dravet
#
#                          Disease  initial_pubmed_count  ...  unique_mondo  \
# 0        spinal_muscular_atrophy                    98  ...            11
# 1   mucopolysaccharidosis_type_i                   100  ...            10
# 2             tuberous_sclerosis                    98  ...            20
# 3                 celiac_disease                  2000  ...            90
# 4              hypochondroplasia                    13  ...             6
# 5                 apert_syndrome                    50  ...             5
# 6             huntington_disease                   226  ...            18
# 7              hypochondroplasia                    13  ...             6
# 8                 milroy_disease                     2  ...             1
# 9                 milroy_disease                     2  ...             1
# 10               marfan_syndrome                   150  ...            14
# 11                  alkaptonuria                    42  ...             4
# 12         ataxia_telangiectasia                   100  ...            10
# 13      chediak_higashi_syndrome                    48  ...             7
# 14        donnai-barrow_syndrome                     3  ...             1
# 15               gaucher_disease                    99  ...            10
# 16               gaucher_disease                    99  ...            10
# 17     maple_syrup_urine_disease                    99  ...            15
# 18       spinal_muscular_atrophy                    98  ...            11
# 19       spinal_muscular_atrophy                    98  ...            11
# 20       spinal_muscular_atrophy                    98  ...            11
# 21               canavan_disease                    39  ...             8
# 22                wilson_disease                   252  ...            29
# 23          lesch_nyhan_syndrome                    50  ...             1
# 24                 rett_syndrome                   100  ...            10
# 25                 citrullinemia                    50  ...            12
# 26                   sickle_cell                  2000  ...            55
# 27            propionic_acidemia                    50  ...             8
# 28              brugada_syndrome                    27  ...             5
# 29    primary_ciliary_dyskinesia                    98  ...            12
# 30  familial_mediterranean_fever                   100  ...            22
# 31               gaucher_disease                    99  ...            10
# 32          loeys_dietz_syndrome                    35  ...             2
# 33               noonan_syndrome                   129  ...            38
# 34             stickler_syndrome                    28  ...             9
# 35                fanconi_anemia                   100  ...            10
# 36               dravet_syndrome                    99  ...             8
#
#     total_mondo  total_non_grounded  non_grounded_maxo  non_grounded_hpo  \
# 0           226                 685                313               243
# 1           229                 516                234               222
# 2           230                 605                296               210
# 3          2846                9917               4405              3640
# 4            26                  80                 32                33
# 5           130                 385                165               154
# 6           343                 912                434               358
# 7            26                  80                 32                33
# 8            15                  22                 10                12
# 9            15                  22                 10                12
# 10          229                1124                477               369
# 11           72                 235                102                94
# 12          101                 433                174               156
# 13           92                 351                140               136
# 14           13                  27                 12                 8
# 15          244                 710                323               266
# 16          244                 710                323               266
# 17          231                 610                253               267
# 18          226                 685                313               243
# 19          226                 685                313               243
# 20          226                 685                313               243
# 21           45                 162                 63                68
# 22          628                1876                809               732
# 23           75                 193                 80                77
# 24          111                 371                151               155
# 25          142                 302                129               135
# 26         2466                7899               3377              3159
# 27           93                 312                120               124
# 28           42                 143                 65                47
# 29          244                 634                294               259
# 30          323                 685                344               287
# 31          244                 710                323               266
# 32           85                 271                121                96
# 33          261                 777                349               289
# 34           79                 156                 88                47
# 35          163                 598                230               242
# 36          239                 605                301               201
#
#     non_grounded_mondo  total_potential  potential_maxo  potential_hpo  \
# 0                  129               16               2             11
# 1                   60               13               4              4
# 2                   99               15               3              7
# 3                 1872              158              20             96
# 4                   15                1               1              0
# 5                   66               10               3              4
# 6                  120               22               7             10
# 7                   15                1               1              0
# 8                    0                0               0              0
# 9                    0                0               0              0
# 10                 278               23               4             10
# 11                  39                4               1              1
# 12                 103               14               3              4
# 13                  75               13               5              5
# 14                   7                2               0              1
# 15                 121               11               4              2
# 16                 121               11               4              2
# 17                  90               10               5              2
# 18                 129               16               2             11
# 19                 129               16               2             11
# 20                 129               16               2             11
# 21                  31                4               1              0
# 22                 335               33              10             14
# 23                  36               10               4              5
# 24                  65                7               3              2
# 25                  38               11               1              5
# 26                1363              102              25             51
# 27                  68               12               2              6
# 28                  31                8               1              5
# 29                  81               20               5             12
# 30                  54               12               1              4
# 31                 121               11               4              2
# 32                  54                4               1              1
# 33                 139               25               2             11
# 34                  21               13               4              6
# 35                 126               25               8              6
# 36                 103                9               1              4
#
#     potential_mondo
# 0                 3
# 1                 5
# 2                 5
# 3                42
# 4                 0
# 5                 3
# 6                 5
# 7                 0
# 8                 0
# 9                 0
# 10                9
# 11                2
# 12                7
# 13                3
# 14                1
# 15                5
# 16                5
# 17                3
# 18                3
# 19                3
# 20                3
# 21                3
# 22                9
# 23                1
# 24                2
# 25                5
# 26               26
# 27                4
# 28                2
# 29                3
# 30                7
# 31                5
# 32                2
# 33               12
# 34                3
# 35               11
# 36                4
#
# [37 rows x 29 columns]

# %%
# Save full_df to an Excel file
full_disease_analysis_df.to_excel('full_disease_analysis_all_diseases.xlsx', index=False)

# Save disease_summary to an Excel file
disease_summary_automaxo.to_excel('disease_summary_automaxo.xlsx', index=False)

# Save maxo_final_curation_df to an Excel file
maxo_final_curation_df.to_excel('full_maxo_final_curation.xlsx', index=False)

summary_curation.to_excel('maxo_final_curation.xlsx', index=False)

merged_curation_automaxo_df.to_excel('merged_curation_automaxo.xlsx', index=False)
