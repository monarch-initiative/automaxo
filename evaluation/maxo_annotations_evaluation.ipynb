# %%
import pandas as pd

# %%
maxo_annotations_df = pd.read_csv('maxo-annotations.tsv', delimiter='\t')
evaluation_no_replacement_df = pd.read_csv('evaluation_no_replacement.tsv', delimiter='\t')

# %%
maxo_annotations_desired_df = maxo_annotations_df[['disease_id', 'disease_name', 'citation', 'maxo_id', 'maxo_label', 'hpo_id', 'maxo_relation']]

# %%
annotated_pm_ids = maxo_annotations_desired_df['citation']
annotated_pm_ids_list = annotated_pm_ids.tolist()
# Extract numeric part, remove duplicates, and filter out invalid elements
annotated_pm_ids = set(id.split(':')[1] for id in annotated_pm_ids_list if id.startswith('PMID:'))
len(annotated_pm_ids)
# Out:
# 189

# %%
retrieved_pmids= set(evaluation_no_replacement_df.iloc[:, 0])
# Convert set1 to a set of strings
retrieved_pmids = {str(item) for item in retrieved_pmids}

len(retrieved_pmids)
# Out:
# 61

# %%
non_retrieved_pmids =  annotated_pm_ids - retrieved_pmids

# %%
len(non_retrieved_pmids)
# Out:
# 128

# %%
maxo_annotations_desired_df
# Out:
#         disease_id                                       disease_name  \
# 0    MONDO:0008854                            Bardet-biedl Syndrome 1
# 1    MONDO:0008854                            Bardet-biedl Syndrome 1
# 2    MONDO:0008854                            Bardet-biedl Syndrome 1
# 3    MONDO:0008854                            Bardet-biedl Syndrome 1
# 4    MONDO:0021056                         Adenomatous Polyposis Coli
# ..             ...                                                ...
# 408  MONDO:0021056                         Adenomatous Polyposis Coli
# 409  MONDO:0021056                         Adenomatous Polyposis Coli
# 410  MONDO:0021056                         Adenomatous Polyposis Coli
# 411  MONDO:0011971            Immunodeficiency With Hyper-igm, Type 5
# 412  MONDO:0100079  Epileptic Encephalopathy, Early Infantile, 6 (...
#
#                                         citation       maxo_id  \
# ...

# %%
# Extract numeric part of PubMed IDs and update the 'citation' column
maxo_annotations_desired_df['citation'] = maxo_annotations_desired_df['citation'].apply(lambda x: x.split(':')[1] if x.startswith('PMID:') else x)
# Out:
# /var/folders/p0/qn3c3czj667fgqw88sg__klcr2ymdh/T/ipykernel_29107/2756719998.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   maxo_annotations_desired_df['citation'] = maxo_annotations_desired_df['citation'].apply(lambda x: x.split(':')[1] if x.startswith('PMID:') else x)

# %%
# Define the desired column order
new_column_order = ['citation', 'maxo_id', 'maxo_label','hpo_id', 'maxo_relation', 'disease_id', 'disease_name']
maxo_annotations_desired_df = maxo_annotations_desired_df[new_column_order]
maxo_annotations_desired_df
# Out:
#                                         citation       maxo_id  \
# 0                                       20301537  MAXO:0000088
# 1                                       20301537  MAXO:0000011
# 2                                       20301537  MAXO:0000930
# 3                                       20301537  MAXO:0000088
# 4    https://www.ncbi.nlm.nih.gov/books/NBK1345/  MAXO:0001110
# ..                                           ...           ...
# 408                                     20301519  MAXO:0000646
# 409                                     20301519  MAXO:0000635
# 410                                     20301519  MAXO:0000221
# 411                                     12958596  MAXO:0001480
# 412                                      9596203  MAXO:0000208
#
#                                        maxo_label      hpo_id  \
# 0                            dietary intervention  HP:0000819
# 1                                physical therapy  HP:0002141
# ...

# %%
# Select Annotations for the retrieved articles:
retrived_maxo_annotations_df = maxo_annotations_desired_df[maxo_annotations_desired_df['citation'].isin(retrieved_pmids)].copy()

retrived_maxo_annotations_df
# Out:
#      citation       maxo_id  \
# 138  25405392  MAXO:0000187
# 177  27192671  MAXO:0000286
# 178  27192671  MAXO:0000286
# 180  20140965  MAXO:0000004
# 184  29716835  MAXO:0000933
# ..        ...           ...
# 391  29084731  MAXO:0000185
# 397  15474813  MAXO:0000960
# 399  28237137  MAXO:0001082
# 405  29478819  MAXO:0000933
# 406   9543069  MAXO:0001479
#
#                                             maxo_label         hpo_id  \
# 138           beta-adrenergic antagonist agent therapy     HP:0002616
# 177                   androgen modifying agent therapy  MONDO:0013521
# 178                   androgen modifying agent therapy  MONDO:0013878
# 180                                 surgical procedure     HP:0010628
# 184      enzyme replacement or supplementation therapy  MONDO:0009561
# ..                                                 ...            ...
# 391                        antiarrythmic agent therapy     HP:0004308
# ...

# %%
# Select Annotations for the retrieved articles:
non_retrived_maxo_annotations_df = maxo_annotations_desired_df[maxo_annotations_desired_df['citation'].isin(non_retrieved_pmids)].copy()
non_retrived_maxo_annotations_df
# Out:
#      citation       maxo_id                                    maxo_label  \
# 0    20301537  MAXO:0000088                          dietary intervention
# 1    20301537  MAXO:0000011                              physical therapy
# 2    20301537  MAXO:0000930                                speech therapy
# 3    20301537  MAXO:0000088                          dietary intervention
# 8    20301675  MAXO:0000004                            surgical procedure
# ..        ...           ...                                           ...
# 408  20301519  MAXO:0000646                           cancer chemotherapy
# 409  20301519  MAXO:0000635                   anti-estrogen agent therapy
# 410  20301519  MAXO:0000221  nonsteroidal anti-inflammatory agent therapy
# 411  12958596  MAXO:0001480               immunoglobulin infusion therapy
# 412   9596203  MAXO:0000208              sodium channel inhibitor therapy
#
#          hpo_id    maxo_relation     disease_id  \
# ...

# %%
import pandas as pd
import json

# %%
# Read final Json File
post_ontoGPT_file_path = "evaluation_post_ontoGPT.json"

# %%
# Load JSON data from file
with open(post_ontoGPT_file_path, 'r') as file:
    data = json.load(file)

# %%
# Initialize an empty list to store rows
rows = []

# Iterate through the JSON data and extract the relevant information
for entry in data.get('ranked_triplets'):
    triplet = entry.get('triplet', [])
    if len(triplet) == 3:
        subject_with_label, predicate, object_with_label = triplet
        subject, subject_label = subject_with_label.split(': ', 1)
        object_, object_label = object_with_label.split(': ', 1)
        for pubmed_id in entry.get('pubmed_ids_mesh_info', {}):
            rows.append([subject, subject_label, predicate, object_, object_label, pubmed_id])

# Create a DataFrame from the rows
df = pd.DataFrame(rows, columns=['Subject', 'Subject Label', 'Predicate', 'Object', 'Object Label', 'Citation'])


# Rename 'Subject Label' to 'maxo_label'
df.rename(columns={'Subject Label': 'maxo_label','Subject Label': 'maxo_label' }, inplace=True)

# Initialize new columns
df['maxo_id'] = ''
df['disease_id'] = ''
df['hpo_id'] = ''
df['disease_name'] = ''
df['hpo_label'] = ''

# Function to extract terms
def extract_terms(row):
    if 'MAXO:' in row['Subject']:
        row['maxo_id'] = row['Subject']
        row['Subject'] = ''
    if 'MONDO:' in row['Object']:
        row['disease_id'] = row['Object']
        row['disease_name'] = row['Object Label']
        row['Object'] = ''
    if 'HP:' in row['Object']:
        row['hpo_id'] = row['Object']
        row['hpo_label'] = row['Object Label']
        row['Object'] = ''
    return row

# Apply function to each row
df_new = df.apply(extract_terms, axis=1)

# Reorder columns
df_new = df_new[['Citation', 'maxo_id', 'maxo_label', 'Subject', 'Predicate', 'disease_id', 'disease_name', 'hpo_id', 'hpo_label', 'Object']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/maxo/automaxo/.venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ungrounded_object'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[68], line 44
#      41     return row
# ...

# %%
df_new
# Out:
#      Citation       maxo_id              maxo_label                 Subject  \
# 0     9389690                                              T-cell depletion
# 1    11316696  MAXO:0000780  growth hormone therapy
# 2    15956085  MAXO:0000780  growth hormone therapy
# 3    11316696  MAXO:0000780  growth hormone therapy
# 4    15956085  MAXO:0000780  growth hormone therapy
# ..        ...           ...                     ...                     ...
# 221  32389449                                        ketogenic diet therapy
# 222  32389449                                        ketogenic diet therapy
# 223   5658866                                            folic acid therapy
# 224   5658866                                            folic acid therapy
# 225   5658866                                            folic acid therapy
#
#                Predicate     disease_id     disease_name      hpo_id  \
# 0    IS USED TO MINIMIZE
# ...

# %%
# Sample data
data = {
    'Subject': ['T-cell depletion', 'MAXO:0000780', 'MAXO:0000780', 'MAXO:0000780', 'MAXO:0000780', 'ketogenic diet therapy', 'ketogenic diet therapy', 'folic acid therapy', 'folic acid therapy', 'folic acid therapy'],
    'Subject Label': ['', 'growth hormone therapy', 'growth hormone therapy', 'growth hormone therapy', 'growth hormone therapy', '', '', '', '', ''],
    'Predicate': ['IS USED TO MINIMIZE', 'TREATS', 'TREATS', 'IS USED TO TREAT', 'IS USED TO TREAT', 'TREATS', 'IS USED TO TREAT', 'TREATS', 'IS USED TO TREAT', 'IS USED TO TREAT'],
    'Object': ['graft rejection', 'MONDO:0018997', 'MONDO:0018997', 'HP:0004322', 'HP:0004322', 'MONDO:0010998', 'intractable seizures', 'MONDO:0004737', 'Subnormal serum folate levels', 'increased folate clearance'],
    'Object Label': ['', 'Noonan syndrome', 'Noonan syndrome', 'short stature', 'short stature', 'ALG3-CDG', '', 'Homocystinuria', '', ''],
    'Citation': [9389690, 11316696, 15956085, 11316696, 15956085, 32389449, 32389449, 5658866, 5658866, 5658866]
}

# %%
Citation: ex [9389690, 11316696]
MaXO Terms: ex 'MAXO:0000780' (if it part of the subject but has MAXO in its name)
Subject: 'T-cell depletion'' (if it is part of subject but does not have maxo term in its content)
Subject Labels:  'growth hormone therapy'
Predicate : 'TREATS'
MONDO Terms: 'MONDO:0018997''
HPO Terms: 'HP:0004322'
Object: 'graft rejection' (if it is part of object but neither MONDO nor HPO)
Object Labels'Noonan syndrome' (labels don't change)

# %%
data = {
    'Subject': ['T-cell depletion', 'MAXO:0000780', 'MAXO:0000780', 'MAXO:0000780', 'MAXO:0000780', 'ketogenic diet therapy', 'ketogenic diet therapy', 'folic acid therapy', 'folic acid therapy', 'folic acid therapy'],
    'Subject Label': ['', 'growth hormone therapy', 'growth hormone therapy', 'growth hormone therapy', 'growth hormone therapy', '', '', '', '', ''],
    'Predicate': ['IS USED TO MINIMIZE', 'TREATS', 'TREATS', 'IS USED TO TREAT', 'IS USED TO TREAT', 'TREATS', 'IS USED TO TREAT', 'TREATS', 'IS USED TO TREAT', 'IS USED TO TREAT'],
    'Object': ['graft rejection', 'MONDO:0018997', 'MONDO:0018997', 'HP:0004322', 'HP:0004322', 'MONDO:0010998', 'intractable seizures', 'MONDO:0004737', 'Subnormal serum folate levels', 'increased folate clearance'],
    'Object Label': ['', 'Noonan syndrome', 'Noonan syndrome', 'short stature', 'short stature', 'ALG3-CDG', '', 'Homocystinuria', '', ''],
    'Citation': [9389690, 11316696, 15956085, 11316696, 15956085, 32389449, 32389449, 5658866, 5658866, 5658866]
}

# Create DataFrame
df = pd.DataFrame(data)

# %%
df
# Out:
#                   Subject           Subject Label            Predicate  \
# 0        T-cell depletion                          IS USED TO MINIMIZE
# 1            MAXO:0000780  growth hormone therapy               TREATS
# 2            MAXO:0000780  growth hormone therapy               TREATS
# 3            MAXO:0000780  growth hormone therapy     IS USED TO TREAT
# 4            MAXO:0000780  growth hormone therapy     IS USED TO TREAT
# 5  ketogenic diet therapy                                       TREATS
# 6  ketogenic diet therapy                             IS USED TO TREAT
# 7      folic acid therapy                                       TREATS
# 8      folic acid therapy                             IS USED TO TREAT
# 9      folic acid therapy                             IS USED TO TREAT
#
#                           Object     Object Label  Citation
# 0                graft rejection                    9389690
# 1                  MONDO:0018997  Noonan syndrome  11316696
# ...

# %%
# Initialize new columns
df['maxo_id'] = ''
df['disease_id'] = ''
df['hpo_id'] = ''

# Function to extract terms
def extract_terms(row):
    if 'MAXO:' in row['Subject']:
        row['maxo_id'] = row['Subject']
        row['Subject'] = ''
    if 'MONDO:' in row['Object']:
        row['disease_id'] = row['Object']
        row['Object'] = ''
    if 'HP:' in row['Object']:
        row['hpo_id'] = row['Object']
        row['Object'] = ''
    return row

# Apply function to each row
df_new = df.apply(extract_terms, axis=1)

# Reorder columns
df_new = df_new[['Citation', 'maxo_id', 'Subject Label', 'Subject', 'Predicate', 'disease_id', 'hpo_id', 'Object Label', 'Object']]

# %%
non_retrived_maxo_annotations_df.columns
# Out:
# Index(['citation', 'maxo_id', 'maxo_label', 'hpo_id', 'maxo_relation',
#        'disease_id', 'disease_name'],
#       dtype='object')

# %%
df_new
# Out:
#    Citation       maxo_id           Subject Label                 Subject  \
# 0   9389690                                              T-cell depletion
# 1  11316696  MAXO:0000780  growth hormone therapy
# 2  15956085  MAXO:0000780  growth hormone therapy
# 3  11316696  MAXO:0000780  growth hormone therapy
# 4  15956085  MAXO:0000780  growth hormone therapy
# 5  32389449                                        ketogenic diet therapy
# 6  32389449                                        ketogenic diet therapy
# 7   5658866                                            folic acid therapy
# 8   5658866                                            folic acid therapy
# 9   5658866                                            folic acid therapy
#
#              Predicate     disease_id      hpo_id     Object Label  \
# 0  IS USED TO MINIMIZE
# 1               TREATS  MONDO:0018997              Noonan syndrome
# 2               TREATS  MONDO:0018997              Noonan syndrome
# ...

# %%
df_new.columns
# Out:
# Index(['Subject', 'Subject Label', 'Predicate', 'Object', 'Object Label',
#        'Citation', 'MAXO Terms', 'MONDO Terms', 'HPO Terms'],
#       dtype='object')

# %%
# Save the retrieved annotations DataFrame to a TSV file
retrived_maxo_annotations_df.to_csv('results/retrieved_maxo_annotations.tsv', sep='\t', index=False)

# Save the non-retrieved annotations DataFrame to a TSV file
non_retrived_maxo_annotations_df.to_csv('results/non_retrieved_maxo_annotations.tsv', sep='\t', index=False)

# Save the post-OntoGPT triplet DataFrame to a TSV file
post_ontoGPT_triplet_df.to_csv('results/post_ontoGPT_triplet.tsv', sep='\t', index=False)
