# %%
# Analysis of all the unique triplets extracted

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
sickle_cell_summary_path = "../../data/sickle_cell/summary_post_ontoGPT.tsv"

# %%
sickle_cell_summary_df = pd.read_csv(sickle_cell_summary_path, sep='\t')

# %%
sickle_cell_summary_df.tail()
# Out:
#       Citation Subject Subject Label  \
# 4391  34152394     NaN           NaN
# 4392  34152394     NaN           NaN
# 4393  34152394     NaN           NaN
# 4394  34152394     NaN           NaN
# 4395  34152394     NaN           NaN
#
#                                   Non grounded Subject Potential MAXO  \
# 4391              calculation of exact red cell volume             []
# 4392  increasing the targeted end procedure hematocrit             []
# 4393          suppression of endogenous erythropoiesis             []
# 4394                           red cell exchange (rce)             []
# 4395                        transfusing red cell units             []
#
#      Predicate Object Object Label    Non grounded Object  \
# 4391    treats    NaN          NaN  severe blood shortage
# 4392    treats    NaN          NaN  severe blood shortage
# 4393    treats    NaN          NaN  severe blood shortage
# 4394    treats    NaN          NaN  severe blood shortage
# ...

# %%
sickle_cell_summary_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4396 entries, 0 to 4395
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Citation                4396 non-null   int64
#  1   Subject                 457 non-null    object
#  2   Subject Label           457 non-null    object
#  3   Non grounded Subject    3939 non-null   object
#  4   Potential MAXO          4396 non-null   object
#  5   Predicate               4396 non-null   object
#  6   Object                  731 non-null    object
#  7   Object Label            731 non-null    object
#  8   Non grounded Object     3656 non-null   object
#  9   Potential HP            4396 non-null   object
#  10  Qualifier               2734 non-null   object
#  11  Qualifier Label         2734 non-null   object
#  12  Non grounded Qualifier  1287 non-null   object
#  13  Potential MONDO         4396 non-null   object
# ...
